# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in ./.local/lib/python3.8/site-packages (0.24.2)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %%
boston=datasets.load_boston()
print (boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
print(boston.keys())
print(boston.DESCR)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
# ...

# %%
x=boston.data[:, np.newaxis, 5] ## columna 5 del data set average number of rooms per dwelling
y=boston.target ## definr los datos correspindientes a las etiquetas
# 
plt.scatter(x,y)
plt.xlabel("Numero de habitaciones")
plt.ylabel("valor medio")
# Out:
# Text(0, 0.5, 'valor medio')

# %% [markdown]
# # REGRESIÓN LINEAL SIMPLE

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2) ## 20% de los datos


lr= linear_model.LinearRegression() ## se define el modelo a utilizar
lr.fit(x_train,y_train) ## se entrena el modelo
y_pred= lr.predict(x_test) ## se realiza una prediccion

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred, color="red", linewidth=3)
plt.title("Regresión lineal simple")
plt.xlabel("Numero de habitaciones")
plt.ylabel("valor medio")
# Out:
# Text(0, 0.5, 'valor medio')

# %%
##datos de la pendiente
print (lr.coef_) ##valor de a 
print(lr.intercept_)## valor de b
print ("y=ax+b y=",lr.coef_, "x", lr.intercept_)
print(lr.score(x_train,y_train)) ## precision del modelo
# Out:
# [8.9274085]
# -33.51397192218644
# y=ax+b y= [8.9274085] x -33.51397192218644
# 0.48198177355027083

# %% [markdown]
# # REGRESIÓN LINEAL MÚLTIPLE

# %%
x_multiple = boston.data[:, 5:8] ## seleccionamos las columnas 5,6 y 7
print (x_multiple)
y_multiple=boston.target
print (y_multiple) ## definr los datos correspindientes a las etiquetas
# Out:
# [[ 6.575  65.2     4.09  ]
#  [ 6.421  78.9     4.9671]
#  [ 7.185  61.1     4.9671]
#  ...
#  [ 6.976  91.      2.1675]
#  [ 6.794  89.3     2.3889]
#  [ 6.03   80.8     2.505 ]]
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
# ...

# %%
xm_train, xm_test, ym_train, ym_test = train_test_split(x_multiple,y_multiple, test_size=0.2)


lr_multiple= linear_model.LinearRegression() ## se define el modelo a utilizar
lr_multiple.fit(xm_train,ym_train) ## se entrena el modelo
ym_pred= lr_multiple.predict(xm_test) ## se realiza una prediccion

# %%
##datos de la pendiente
print (lr_multiple.coef_) ##coeficientes de a 
print(lr_multiple.intercept_)## valor de b
print ("y=a1x1+a2x2+a3x3+anxn+b y=",lr_multiple.coef_, "x", lr_multiple.intercept_)
print(lr_multiple.score(xm_train,ym_train)) ## precision del modelo
# Out:
# [ 8.26839762 -0.10446053 -0.56837174]
# -20.20633636344254
# y=a1x1+a2x2+a3x3+anxn+b y= [ 8.26839762 -0.10446053 -0.56837174] x -20.20633636344254
# 0.5292395453378393

# %%
plt.scatter(xm_test,ym_test)
plt.plot(xm_test, ym_pred, color="red", linewidth=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e788d97f9b8d> in <module>
# ----> 1 plt.scatter(xm_test,ym_test)
#       2 plt.plot(xm_test, ym_pred, color="red", linewidth=3)
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2871         verts=cbook.deprecation._deprecated_parameter,
#    2872         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2873     __ret = gca().scatter(
#    2874         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2875         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1431     def inner(ax, *args, data=None, **kwargs):
#    1432         if data is None:
# ...

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler
x_pca = boston.data[:, 5:8] ## seleccionamos las columnas 5,6 y 7
print (x_pca)
y_pca=boston.target
print (y_pca) ## definr los datos correspindientes a las etiquetas
x = StandardScaler().fit_transform(x_pca)
# Out:
# [[ 6.575  65.2     4.09  ]
#  [ 6.421  78.9     4.9671]
#  [ 7.185  61.1     4.9671]
#  ...
#  [ 6.976  91.      2.1675]
#  [ 6.794  89.3     2.3889]
#  [ 6.03   80.8     2.505 ]]
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x_pca)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e7d4ef6f138> in <module>
#       1 from sklearn.decomposition import PCA
#       2 pca = PCA(n_components=2)
# ----> 3 principalComponents = pca.fit_transform(x_pca)
#       4 principalDf = pd.DataFrame(data = principalComponents
#       5              , columns = ['principal component 1', 'principal component 2'])
#
# NameError: name 'x_pca' is not defined

# %%
from sklearn.decomposition import PCA

from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


# #############################################################################
# Create the data

e = np.exp(1)
np.random.seed(4)


def pdf(x):
    return 0.5 * (stats.norm(scale=0.25 / e).pdf(x)
                  + stats.norm(scale=4 / e).pdf(x))

y = np.random.normal(scale=0.5, size=(30000))
x = np.random.normal(scale=0.5, size=(30000))
z = np.random.normal(scale=0.1, size=len(x))

density = pdf(x) * pdf(y)
pdf_z = pdf(5 * z)

density *= pdf_z

a = x + y
b = 2 * y
c = a - b + z

norm = np.sqrt(a.var() + b.var())
a /= norm
b /= norm


# #############################################################################
# Plot the figures
def plot_figs(fig_num, elev, azim):
    fig = plt.figure(fig_num, figsize=(4, 3))
    plt.clf()
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=elev, azim=azim)

    ax.scatter(a[::10], b[::10], c[::10], c=density[::10], marker='+', alpha=.4)
    Y = np.c_[a, b, c]

    # Using SciPy's SVD, this would be:
    # _, pca_score, Vt = scipy.linalg.svd(Y, full_matrices=False)

    pca = PCA(n_components=3)
    pca.fit(Y)
    V = pca.components_.T

    x_pca_axis, y_pca_axis, z_pca_axis = 3 * V
    x_pca_plane = np.r_[x_pca_axis[:2], - x_pca_axis[1::-1]]
    y_pca_plane = np.r_[y_pca_axis[:2], - y_pca_axis[1::-1]]
    z_pca_plane = np.r_[z_pca_axis[:2], - z_pca_axis[1::-1]]
    x_pca_plane.shape = (2, 2)
    y_pca_plane.shape = (2, 2)
    z_pca_plane.shape = (2, 2)
    ax.plot_surface(x_pca_plane, y_pca_plane, z_pca_plane)
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])


elev = -40
azim = -80
plot_figs(1, elev, azim)

elev = 30
azim = 20
plot_figs(2, elev, azim)

plt.show()

# %%
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets import make_blobs

# #############################################################################
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, _ = make_blobs(n_samples=10000, centers=centers, cluster_std=0.6)

# #############################################################################
# Compute clustering with MeanShift

# The following bandwidth can be automatically detected using
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)

# #############################################################################
# Plot result
import matplotlib.pyplot as plt
from itertools import cycle

plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# number of estimated clusters : 3
